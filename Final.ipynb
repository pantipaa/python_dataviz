# %%
import pandas as pd

# %%
covid = "C:\\Users\\admin\\Downloads\\2019_nCoV_data.csv"

# %%
covid_df=pd.read_csv(covid)

# %%
covid_df
# Out:
#        Sno                 Date   Province/State Country          Last Update  \
# 0        1  01/22/2020 12:00:00            Anhui   China  01/22/2020 12:00:00
# 1        2  01/22/2020 12:00:00          Beijing   China  01/22/2020 12:00:00
# 2        3  01/22/2020 12:00:00        Chongqing   China  01/22/2020 12:00:00
# 3        4  01/22/2020 12:00:00           Fujian   China  01/22/2020 12:00:00
# 4        5  01/22/2020 12:00:00            Gansu   China  01/22/2020 12:00:00
# ...    ...                  ...              ...     ...                  ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI      US  2020-02-05T21:53:02
# 1715  1716  02/17/2020 22:00:00       Orange, CA      US  2020-02-01T19:53:03
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX      US  2020-02-13T18:53:02
# 1717  1718  02/17/2020 22:00:00      Seattle, WA      US  2020-02-09T07:03:04
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ      US  2020-02-01T19:43:03
#
# ...

# %%
set(covid_df['Country'])
# Out:
# {'Australia',
#  'Belgium',
#  'Brazil',
#  'Cambodia',
#  'Canada',
#  'China',
#  'Egypt',
#  'Finland',
#  'France',
#  'Germany',
#  'Hong Kong',
#  'India',
#  'Italy',
#  'Ivory Coast',
#  'Japan',
#  'Macau',
#  'Mainland China',
#  'Malaysia',
#  'Mexico',
#  'Nepal',
#  'Others',
#  'Philippines',
#  'Russia',
#  'Singapore',
#  'South Korea',
#  'Spain',
#  'Sri Lanka',
#  'Sweden',
#  'Taiwan',
#  'Thailand',
#  'UK',
#  'US',
#  'United Arab Emirates',
#  'Vietnam'}

# %%
data_covid = covid_df[covid_df['Country']!='China']

# %%
data_covid
# Out:
#        Sno                 Date   Province/State         Country  \
# 31      32  01/22/2020 12:00:00       Washington              US
# 35      36  01/22/2020 12:00:00              NaN           Japan
# 36      37  01/22/2020 12:00:00              NaN        Thailand
# 37      38  01/22/2020 12:00:00              NaN     South Korea
# 38      39  01/23/2020 12:00:00            Anhui  Mainland China
# ...    ...                  ...              ...             ...
# 1714  1715  02/17/2020 22:00:00      Madison, WI              US
# 1715  1716  02/17/2020 22:00:00       Orange, CA              US
# 1716  1717  02/17/2020 22:00:00  San Antonio, TX              US
# 1717  1718  02/17/2020 22:00:00      Seattle, WA              US
# 1718  1719  02/17/2020 22:00:00        Tempe, AZ              US
#
#               Last Update  Confirmed  Deaths  Recovered
# 31    01/22/2020 12:00:00          1       0          0
# 35    01/22/2020 12:00:00          2       0          0
# ...

# %%
datacovid.isnull().any()
# Out:
# Province/State     True
# Country           False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
datacovid = data_covid[['Province/State','Country','Confirmed','Deaths','Recovered']]

# %%
datacovid
# Out:
#        Province/State         Country  Confirmed  Deaths  Recovered
# 31         Washington              US          1       0          0
# 35                NaN           Japan          2       0          0
# 36                NaN        Thailand          2       0          0
# 37                NaN     South Korea          1       0          0
# 38              Anhui  Mainland China          9       0          0
# ...               ...             ...        ...     ...        ...
# 1714      Madison, WI              US          1       0          0
# 1715       Orange, CA              US          1       0          0
# 1716  San Antonio, TX              US          1       0          0
# 1717      Seattle, WA              US          1       0          1
# 1718        Tempe, AZ              US          1       0          0
#
# [1685 rows x 5 columns]

# %%
datacovidfi = datacovid[datacovid['Country']!='Mainland China']

# %%
datacovidfi
# Out:
#        Province/State      Country  Confirmed  Deaths  Recovered
# 31         Washington           US          1       0          0
# 35                NaN        Japan          2       0          0
# 36                NaN     Thailand          2       0          0
# 37                NaN  South Korea          1       0          0
# 50          Hong Kong    Hong Kong          2       0          0
# ...               ...          ...        ...     ...        ...
# 1714      Madison, WI           US          1       0          0
# 1715       Orange, CA           US          1       0          0
# 1716  San Antonio, TX           US          1       0          0
# 1717      Seattle, WA           US          1       0          1
# 1718        Tempe, AZ           US          1       0          0
#
# [884 rows x 5 columns]

# %%
datacovidfi_dropsome = datacovidfi.dropna(subset = ['Province/State'])

# %%
datacovidfi_dropsome
# Out:
#        Province/State    Country  Confirmed  Deaths  Recovered
# 31         Washington         US          1       0          0
# 50          Hong Kong  Hong Kong          2       0          0
# 58              Macau      Macau          2       0          0
# 66             Taiwan     Taiwan          1       0          0
# 69         Washington         US          1       0          0
# ...               ...        ...        ...     ...        ...
# 1714      Madison, WI         US          1       0          0
# 1715       Orange, CA         US          1       0          0
# 1716  San Antonio, TX         US          1       0          0
# 1717      Seattle, WA         US          1       0          1
# 1718        Tempe, AZ         US          1       0          0
#
# [422 rows x 5 columns]

# %%
datacovidfi_dropsome.isnull().any()
# Out:
# Province/State    False
# Country           False
# Confirmed         False
# Deaths            False
# Recovered         False
# dtype: bool

# %%
datacovidfi_df = datacovidfi_dropsome.groupby('Country')

# %%
datacovidfi_df.first()
# Out:
#             Province/State  Confirmed  Deaths  Recovered
# Country
# Australia  New South Wales          4       0          0
# Canada             Ontario          1       0          0
# Germany            Bavaria          1       0          0
# Hong Kong        Hong Kong          2       0          0
# Macau                Macau          2       0          0
# Others         Cruise Ship         61       0          0
# Taiwan              Taiwan          1       0          0
# US              Washington          1       0          0

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib
import matplotlib.pyplot as plt

# %%
datacovidfi_df.plot(kind='bar', x='Province/State', y='Confirmed', color='y')
plt.show()
