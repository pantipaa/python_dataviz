# %%
import pandas

# %% [markdown]
# #### Define path to table files
# ไฟล์ที่อยู่ในfolderอื่น เลือกเข้าjupyter

# %%
w_restaurant_PATH = 'C:\\Users\\admin\\Documents\\datawarehouse\\w_restaurant.csv'
search_click_PATH = 'C:\\Users\\admin\\Documents\\datawarehouse\\search_click.csv'

# %% [markdown]
# #### load files into memory  โหลดไฟล์เข้ามาใน python

# %%
w_restaurant_df = pandas.read_csv(w_restaurant_PATH)
search_click_df = pandas.read_csv(search_click_PATH)

# %% [markdown]
# #### look at the table

# %%
w_restaurant_df
# Out:
#             id          name  domain_id  closed                    city_name  \
# 61         114      มานีมีนม          1       0  Bangkok Metropolitan Region
# 114        224  สเต็กลุงหนวด          1       0  Bangkok Metropolitan Region
# 115        225      Mr.shake          1       0  Bangkok Metropolitan Region
# 131        267           KFC          1       0  Bangkok Metropolitan Region
# 140        297    Miss Mamon          1       1  Bangkok Metropolitan Region
# ...        ...           ...        ...     ...                          ...
# 246722  339787  Chang coffee          1       0                   Chiang Mai
# 246752  339864      Hokkaido          1       0  Bangkok Metropolitan Region
# 246815  340000  สเต็กลุงหนวด          1       0                 Nakhon Sawan
# 246834  340048     Kuppadeli          1       1  Bangkok Metropolitan Region
# 246842  340068    Sushi Tama          1       0  Bangkok Metropolitan Region
#
# ...

# %%
search_click_df.head()
# Out:
#   click_timestamp                             search_id  business_id  \
# 0         11:38.9  5c004472-5ecc-4159-9698-9f329b8e26e1     298839.0
# 1         30:51.3  5f34eca0-c04e-4c10-b600-54aa447dbd8e     171372.0
# 2         32:09.6  8dc6d1f0-11f1-4239-9dd2-5c1674c81224      16157.0
# 3         00:59.8  1a5810e9-3d1f-44b9-9a2e-26ede21c524b      89741.0
# 4         23:36.8  6bc75e0d-fc65-471e-9926-ff6be6708639     189564.0
#
#    display_position  time_diff_nanos   ads
# 0                 0     2.222400e+15  True
# 1                 0     4.608380e+14  True
# 2                 0     2.581490e+15  True
# 3                 1     1.404580e+15  True
# 4                 1     9.333590e+14  True

# %%
search_click_df.tail()
# Out:
#         click_timestamp                             search_id  business_id  \
# 1048570         05:28.8  99aab616-6fc5-4fbf-994b-4aebee7bb360     278479.0
# 1048571         15:28.8  d70a2c5d-ee94-4e4c-9f7c-c5faac6db12a     321885.0
# 1048572         11:49.4  4c1de7fe-300e-41aa-9d01-914344fc3753     221035.0
# 1048573         10:33.7  2ec0ddec-e450-4b98-9779-42b77aa7eda5     220572.0
# 1048574         13:51.4  5741d9cf-b9f1-441d-aa83-d2b0179bf874     310448.0
#
#          display_position  time_diff_nanos    ads
# 1048570                 8     2.072630e+11  False
# 1048571                 8     6.931413e+10  False
# 1048572                 8     3.105162e+10  False
# 1048573                 8     7.848904e+10  False
# 1048574                 8     3.157757e+10  False

# %%
search_click_df.shape    ###ดูรูปร่างของาราง
# Out:
# (1048575, 6)

# %% [markdown]
# # data preprocessing

# %% [markdown]
# ### missing   ค่าที่ไม่มีในตาราง

# %%
w_restaurant_df.isnull().any()  #### เพิ่มany()จะทำใหดูง่ายขึ้น จะได้รุ้ว่ามีtrueมั้ย
# Out:
# id                         False
# name                       False
# domain_id                  False
# closed                     False
# city_name                  False
# zipcode                     True
# geohash                    False
# new_open                   False
# weighted_average_rating    False
# number_of_chains            True
# number_of_bookmarks         True
# number_of_reviews          False
# number_of_product_tags     False
# total_number_of_views      False
# number_of_checkins         False
# number_of_menu_groups      False
# number_of_menu_photos      False
# category_name              False
# price_range                 True
# avg_price                   True
# parking                     True
# credit_card_accepted        True
# good_for_groups             True
# good_for_kids               True
# bookable                    True
# best_of_wongnai             True
# wifi                        True
# number_of_seats             True
# ...

# %% [markdown]
# ### delete row with missing value  ใช้ลบทุกๆ recodeที่ไท่มีซิปโค้ด

# %%
w_restaurant_df.dropna(subset = ['zipcode','number_of_chains'])
# Out:
#             id          name  domain_id  closed                    city_name  \
# 61         114      มานีมีนม          1       0  Bangkok Metropolitan Region
# 114        224  สเต็กลุงหนวด          1       0  Bangkok Metropolitan Region
# 115        225      Mr.shake          1       0  Bangkok Metropolitan Region
# 131        267           KFC          1       0  Bangkok Metropolitan Region
# 140        297    Miss Mamon          1       1  Bangkok Metropolitan Region
# ...        ...           ...        ...     ...                          ...
# 246722  339787  Chang coffee          1       0                   Chiang Mai
# 246752  339864      Hokkaido          1       0  Bangkok Metropolitan Region
# 246815  340000  สเต็กลุงหนวด          1       0                 Nakhon Sawan
# 246834  340048     Kuppadeli          1       1  Bangkok Metropolitan Region
# 246842  340068    Sushi Tama          1       0  Bangkok Metropolitan Region
#
# ...

# %%
w_restaurant_df = w_restaurant_df.dropna(subset = ['zipcode','number_of_chains'])

# %% [markdown]
# ## fill default value to the data

# %%
w_restaurant_df['parking'].fillna(0)   ##เติมค่า0
# Out:
# 61        3.0
# 114       3.0
# 115       0.0
# 131       3.0
# 140       3.0
#          ...
# 246722    1.0
# 246752    3.0
# 246815    3.0
# 246834    0.0
# 246842    3.0
# Name: parking, Length: 13669, dtype: float64

# %%
w_restaurant_df['parking'] = w_restaurant_df['parking'].fillna(0)  ##
# Out:
# C:\Users\admin\Miniconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## select part of the table by value   การลือกบางส่วนของตารางจะใช้ค่า  b
# #### part of table = table[data_condition == True]

# %%
w_restaurant_df['parking'] > 5
# Out:
# 61        False
# 114       False
# 115       False
# 131       False
# 140       False
#           ...
# 246722    False
# 246752    False
# 246815    False
# 246834    False
# 246842    False
# Name: parking, Length: 13669, dtype: bool

# %%
w_restaurant_df[w_restaurant_df['parking'] >= 3]   ##ฟิวี่มากกว่าหรือเท่ากับ3
# Out:
#             id                             name  domain_id  closed  \
# 61         114                         มานีมีนม          1       0
# 114        224                     สเต็กลุงหนวด          1       0
# 131        267                              KFC          1       0
# 140        297                       Miss Mamon          1       1
# 149        344                  Inthanin Coffee          1       0
# ...        ...                              ...        ...     ...
# 246646  339670  Four Seasons Chinese Restaurant          1       0
# 246684  339718                     Jeffer Steak          1       0
# 246752  339864                         Hokkaido          1       0
# 246815  340000                     สเต็กลุงหนวด          1       0
# 246842  340068                       Sushi Tama          1       0
#
#                           city_name zipcode  geohash  new_open  \
# 61      Bangkok Metropolitan Region   10312  w4rw3e0         0
# ...

# %% [markdown]
# ## HW select all restaurants from your hometown

# %%
w_restaurant_df = pandas.read_csv(w_restaurant_PATH)

# %%
set(w_restaurant_df['city_name'])
# Out:
# {'Abu Dhabi',
#  'Aichi-ken',
#  'Akershus',
#  'Akita-ken',
#  'Al Farwaniyah Governorate',
#  'Alabama',
#  'Alaska',
#  'Alberta',
#  'Amnat Charoen',
#  'Andalucía',
#  'Ang Thong',
#  'Aomori-ken',
#  'Appenzell Ausserrhoden',
#  'Appenzell Innerrhoden',
#  'Aragón',
#  'Argyll and Bute',
#  'Arizona',
#  'Attica',
#  'Auckland',
#  'Australia',
#  'Auvergne-Rhône-Alpes',
#  'Aydın',
#  'Ba Ria - Vung Tau',
#  'Baden-Wurttemberg',
#  'Bago Region',
#  'Bahia',
#  'Bali',
#  'Balochistan',
#  'Bangkok Metropolitan Region',
#  'Banteay Meanchey Province',
#  'Banten',
#  'Basel-Stadt',
#  'Basilicata',
#  'Basrah',
#  'Battambang',
#  'Bay Of Plenty',
#  'Bayern',
#  'Berlin',
#  'Bern',
#  'Bihar',
#  'Binh Thuan',
#  'Binh Thuan province',
#  'Borno',
#  'Bratislava',
#  'Bremen',
#  'Bretagne',
#  'British Columbia',
#  'Brussels Hoofdstedelijk Gewest',
#  'Buckinghamshire',
#  'Budapest',
#  'Bueng Kan',
#  'Buri Ram',
#  'Busan',
#  'Buskerud',
#  'C2 MALL',
#  'CALABARZON',
# ...

# %%
import pandas

# %%
w_restaurant_PATH = 'C:\\Users\\admin\\Documents\\datawarehouse\\w_restaurant.csv'

# %%
w_restaurant_df = pandas.read_csv(w_restaurant_PATH)

# %%
w_restaurant_df_u = w_restaurant_df[w_restaurant_df['city_name']=='Uthai Thani']

# %%
w_restaurant_df['Uthai Thani','w_restaurant_PATH'].fillna(0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Uthai Thani', 'w_restaurant_PATH')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-d5b320b0e93c> in <module>
# ...

# %%
w_restaurant_df['Uthai Thani'] > 5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889             try:
# -> 2890                 return self._engine.get_loc(key)
#    2891             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Uthai Thani'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-00e360e11327> in <module>
# ----> 1 w_restaurant_df['Uthai Thani'] > 5
#
# ...

# %% [markdown]
# ## save table to a file  วิธีsaveตารางลงไฟล์

# %%
w_restaurant_df.to_csv('test.csv')
